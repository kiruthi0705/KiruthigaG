# %% [markdown]
# <a href="https://colab.research.google.com/github/kiruthi0705/KiruthigaG/blob/main/23it031_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='+', color='red')
plt.xlabel("Age")
plt.ylabel("Bought Insurance (0/1)")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df[['age']], df.bought_insurance, train_size=0.8, random_state=42
)

X_test.head()
# Out:
#     age
# 8    62
# 13   29
# 9    61
# 21   26
# 0    22

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predicted = model.predict(X_test)
print("Predictions:", y_predicted)
print("Accuracy:", model.score(X_test, y_test))
# Out:
# Predictions: [1 0 1 0 0 0]
# Accuracy: 1.0

# %%
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficient: [[0.11307708]]
# Intercept: [-4.15311919]

# %%
import math

def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53   # approximated values
    y = sigmoid(z)
    return y

# %%
age = 35
print("Prediction for age 35:", prediction_function(age))

age = 43
print("Prediction for age 43:", prediction_function(age))
# Out:
# Prediction for age 35: 0.4850044983805899
# Prediction for age 43: 0.568565299077705

# %%
age = 78
print("Prediction for age 35:", prediction_function(age))

age = 34
print("Prediction for age 43:", prediction_function(age))
# Out:
# Prediction for age 35: 0.8514475744762746
# Prediction for age 43: 0.474522085522507
